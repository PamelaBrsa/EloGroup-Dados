# %%
import pandas as pd
import plotly.express as px
import matplotlib.pyplot as plt

# %%
#Usando delimitador para ler o erro da linha 3

df = pd.read_csv(r"C:\Users\pamel\OneDrive\Documentos\Case EloGroup\info exames\test_data.csv", delimiter=';')

# %%
#Renomeando para português:

df = df.rename(columns={
    'CodItem': 'Código do Item',
    'Desc Item': 'Descrição do Item',
    'Category': 'Categoria',
    'Family': 'Família',
    'Speciality': 'Especialidade',
    'Testing Cost': 'Custo de Teste'
})

# %%
display(df)
# Out:
#       Código do Item                                  Descrição do Item  \
# 0           70003237  MAGNESIO, SORO (EXEMPLO DE EXPRESSAO DE RESULT...
# 1           70000638                    HEMOGRAMA, AUTOMATIZADO, SANGUE
# 2           70001597                                    FERRITINA, SORO
# 3           70000103  FERRO, DOSAGEM, SORO (EXEMPLO DE EXPRESSAO DE ...
# 4           70000224  CALCIO, DOSAGEM, SORO (EXEMPLO DE EXPRESSAO DE...
# ...              ...                                                ...
# 1997        70008635                  GENES BRCA1 E BRCA2, MLPA, SANGUE
# 1998        70005303  OBSTETRICA 1§ TRIMESTRE (ENDOVAGINAL), SEGUNDO...
# 1999        70006441  HEMOFILIA A, ANALISE DO DNA, SEQUENCIAMENTO, S...
# 2000        70004141                    INSULINA, SORO, 90 MIN APOS XXX
# 2001        70001506                    INSULINA, SORO, 30 MIN APOS XXX
#
#      Categoria     Família     Especialidade  Custo de Teste
# ...

# %%
# Adicionando cifrão na coluna 'Custo de Teste'
df['Custo de Teste'] = '$' + df['Custo de Teste'].astype(str)

# %%
df['Custo de Teste'] = df['Custo de Teste'].str.replace('$', '').astype(float)
# Out:
# C:\Users\pamel\AppData\Local\Temp\ipykernel_18212\3071802498.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Custo de Teste'] = df['Custo de Teste'].str.replace('$', '').astype(float)

# %%
display(df)
# Out:
#       Código do Item                                  Descrição do Item  \
# 0           70003237  MAGNESIO, SORO (EXEMPLO DE EXPRESSAO DE RESULT...
# 1           70000638                    HEMOGRAMA, AUTOMATIZADO, SANGUE
# 2           70001597                                    FERRITINA, SORO
# 3           70000103  FERRO, DOSAGEM, SORO (EXEMPLO DE EXPRESSAO DE ...
# 4           70000224  CALCIO, DOSAGEM, SORO (EXEMPLO DE EXPRESSAO DE...
# ...              ...                                                ...
# 1997        70008635                  GENES BRCA1 E BRCA2, MLPA, SANGUE
# 1998        70005303  OBSTETRICA 1§ TRIMESTRE (ENDOVAGINAL), SEGUNDO...
# 1999        70006441  HEMOFILIA A, ANALISE DO DNA, SEQUENCIAMENTO, S...
# 2000        70004141                    INSULINA, SORO, 90 MIN APOS XXX
# 2001        70001506                    INSULINA, SORO, 30 MIN APOS XXX
#
#      Categoria     Família     Especialidade  Custo de Teste
# ...
